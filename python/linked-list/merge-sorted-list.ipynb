# %% [markdown]
# ### 21. Merge Two Sorted Lists
# - assign dummy node to be like the head of the linked list
# - intialize current node to set the nodes together
# - `while list1 and list2`
# - if `list1.val < list2.val`, point current to list1 and move list1 to the next node
# - else, point current to list2 and move list2 to the next node
# - list1 or list2 might not be equal in size so check if there is nodes left between the two
# - point to the non null node

# %%
class Node:
    def __init__(self, val=0):
        self.val = val
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
    
    def append(self,value):
        new_node = Node(value)

        if not self.head:
            self.head = new_node
            return
        
        current = self.head

        while current.next:
            current = current.next

        current.next = new_node

    def display(self):
        elements = []
        current = self.head
        while current:
            elements.append(current.next)
            current = current.next
        print(elements)

    def merge(self, list1, list2):
        dummy = Node()
        current = dummy

        while list1 and list2:
            if list1.val < list2.val:
                current.next = list1
                list1 = list1.next
            else:
                current.next = list2
                list2 = list2.next
            current = current.next
        if list1:
            current.next = list1
        else:
            current.next = list2

ll1 = LinkedList()
ll1.append(1)
ll1.append(3)
ll1.append(5)

ll2 = LinkedList()
ll2.append(2)
ll2.append(4)
ll2.append(6)

ll1.merge(ll1,ll2)
ll1.display()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 59
#      56 ll2.append(4)
#      57 ll2.append(6)
# ---> 59 ll1.merge(ll1,ll2)
#      60 ll1.display()
#
# Cell In[5], line 37, in LinkedList.merge(self, list1, list2)
#      34 current = dummy
#      36 while list1 and list2:
# ---> 37     if list1.val < list2.val:
#      38         current.next = list1
#      39         list1 = list1.next
#
# AttributeError: 'LinkedList' object has no attribute 'val'

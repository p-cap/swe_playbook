# %% [markdown]
# ### Reorder List

# %% [markdown]
# - find the middle of the problem
# - reverse the second half of the linkedList
# - merge the first and reversed second half of the linkedlist

# %%
# find the middle of the list
"""
slow = head
fast = head.next

while fast and fast.next:
    slow = slow.next
    fast = fast.next.next
"""
# Out:
# '\nslow = head\nfast = head.next\n\nwhile fast and fast.next:\n    slow = slow.next\n    fast = fast.next.next\n'

# %%
# reverse the second half of the linkedlist
"""
current = slow.next
previous = slow.next = None # prevent from cyclic list

while current:
    next_node = current.next
    current.next = previous
    previous = current
    current = next_node
"""
# Out:
# '\ncurrent = slow.next\nprevious = slow..next = None # prevent from cyclic list\n\nwhile current:\n    next_node = current.next\n    current.next = previous\n    previous = current\n    current = next_node\n'

# %%
"""
# merge the first and second half of the list
first = head
second = previous # previous is set as the last node of the second half of the LinkedList

while second: # in odd use cases, second is the shorter of the halves
    tmp1, tmp2 = first.next, second.next

    first.next = second
    second = tmp1

    first, second = tmp1, tmp2
"""
# Out:
# ''

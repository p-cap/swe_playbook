# %% [markdown]
# ### Trapping Rain Water

# %%
height = [0,1,0,2,1,0,1,3,2,1,2,1]

# %% [markdown]
# - initialize with the leftmost and rightmost elements
# - initialize both elements as left and right maxes
# - iterate through using the pointers
# - if left_max is less than right_max, we move the left pointer, otherwise, the right pointer
# - we increment or decrement the pointer based on the left and right values being lesser
# - take the max between the current max and the next height
# - add the difference the max value and the current height

# %%
if not height: print(0)

n = len(height)
left, right = 0, n - 1
left_max = height[left]
right_max = height[right]
result = 0

while left < right:
    # why is this the condition
    # the height matters because we need the minimum height
    if left_max < right_max:
        left += 1 
        left_max = max(left_max, height[left])
        result += left_max - height[left]
    else:
        
        right -= 1
        right_max = max(right_max, height[right])
        result += right_max - height[right]

print(result)
# Out:
# 6

# %% [markdown]
# ### REDO

# %% [markdown]
# - set the two pointers
# - which pointer is less moves
# - the left and right max are tracked
# - the difference between the current max and the current element is added to the result

# %%
t1 = [1,0,1]
expected = 1
n = len(t1)

# %%
left, right = 0, n - 1
left_max, right_max = t1[left], t1[right]
output = 0

# %%
while left < right:
    if left_max < right_max:
        left += 1
        left_max = max(left_max, t1[left])
        output += left_max - t1[left]
    else:
        right -= 1
        right_max = max(right_max, t1[right])
        output += right_max - t1[right]
print(output)
# Out:
# 1

# %% [markdown]
# ### Redo 2
# - opposite end two pointer
# - grab the initialize left and right max based on the pointer value
# - compare the left max and right max values
# - which ever value is lesser
#     - move the pointer
#     - recalculate left max between the left max and left value
#     - get the difference between the left_max and the current left value
#     - add the difference to the output

# %%
height = [4,2,0,3,2,5]
expected = 9
n = len(height)
left, right = 0, n - 1
l_max, r_max = height[left], height[right]
output = 0

while left < right:
    if l_max < r_max:
        left += 1
        l_max = max(l_max, height[left])
        output += l_max - height[left]
    else:
        right += 1
        r_max = max(r_max, height[right])
        output += r_max - height[right]
print(output)
# Out:
# 9

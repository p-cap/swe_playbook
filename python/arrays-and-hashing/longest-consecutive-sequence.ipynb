# %% [markdown]
# #### 128. Longest Consecutive Sequence

# %% [markdown]
# BREAKDOWN:
# - pass the nums array into the set()
# - iterate through each element
# - if the element - 1 is not in num_set, we set the length to 1
# - we check elements that are in num_set that are plus length away from original element
# - take the longest via max between longest and length

# %%
nums = [9,1,4,7,3,-1,0,5,8,-1,6]
expected = 7
length = 0
nums_set = set(nums)   
longest = 0

# %% [markdown]
# - iterating though nums
# - check if the current nums has any number before it
# - check in nums if the element plus length exists within num_set

# %%
for n in nums:
    if n - 1 not in nums_set:
        length = 1
    while n + length in nums_set:            
        length += 1
    longest = max(longest, length)
print(f'longest: {longest}')
print(longest == expected)
# Out:
# longest: 7
# True

# %%
## Parking lot
test = [9,1,4,7,3,-1,0,5,8,-1,6] 
test.sort()
print(test)
length = 0
longest = 0 
# this one is key
nums_set = set(test)
# [9,1,4,7,3,-1,0,5,8,-1,6] 
for num in test:
    if num - 1 not in nums_set:
        print(f'num: {num}')
        length = 1
        while num + length in nums_set:
            length += 1
    print(f'length: {length}')
    longest = max(longest, length)
    
print(longest)
# Out:
# [-1, -1, 0, 1, 3, 4, 5, 6, 7, 8, 9]
# num: -1
# length: 3
# num: -1
# length: 3
# length: 3
# length: 3
# num: 3
# length: 7
# length: 7
# length: 7
# length: 7
# length: 7
# length: 7
# length: 7
# 7

# %% [markdown]
# The while loop needed to be inside the if statement

# %%
## Parking lot
test = [9,1,4,7,3,-1,0,5,8,-1,6] 
test.sort()
print(test)
length = 0
longest = 0 
# this one is key
nums_set = set(test)
# [9,1,4,7,3,-1,0,5,8,-1,6] 
for num in test:
    if num - 1 not in nums_set:
        print(f'num: {num}')
        length = 1
    # when num = 0, the while loop takes num + length which equals 3, 3 is nums_set, so it enters the while loop increment the length until 10
    while num + length in nums_set:
        length += 1
    print(f'length: {length}')
    longest = max(longest, length)
    
print(longest)
# Out:
# [-1, -1, 0, 1, 3, 4, 5, 6, 7, 8, 9]
# num: -1
# length: 3
# num: -1
# length: 3
# length: 10
# length: 10
# num: 3
# length: 7
# length: 7
# length: 7
# length: 7
# length: 7
# length: 7
# length: 7
# 10

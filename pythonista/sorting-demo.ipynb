# %% [markdown]
# ### Using the sort function and its corresponding attributes

# %%
test = [4,1,-1,2,-1,2,3]

# %% [markdown]
# - below is a normal sort

# %%
test.sort()
print(test)
# Out:
# [-1, -1, 1, 2, 2, 3, 4]

# %% [markdown]
# - we can reverse the sort in a descending fashion

# %%
test.sort(reverse=True)
print(test)
# Out:
# [4, 3, 2, 2, 1, -1, -1]

# %% [markdown]
# Using sorted()

# %%
test = 'isortmoko'

# %%
print(sorted(test))
# Out:
# ['i', 'k', 'm', 'o', 'o', 'o', 'r', 's', 't']

# %%
test2 = sorted(test)
print(test2)
# Out:
# ['i', 'k', 'm', 'o', 'o', 'o', 'r', 's', 't']

# %% [markdown]
# Using join to convert it back into a string

# %%
myresult = ''.join(test2)
print(myresult)
# Out:
# ikmooorst

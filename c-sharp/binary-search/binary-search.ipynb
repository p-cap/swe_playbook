// %% [markdown]
// ### 704 Binary Search

// %% [markdown]
//  - List declaration

// %%
// lists
// there are other conventions of declaring a list but I like this one
// the convention below is NOT fixed
List<int> nums = [];
for (int i = 0; i < 10; i++)
{
    nums.Add(i);
}

foreach (int i in nums)
{
    Console.Write(i);
}
// Out:
// 0123456789

// %%
// while loop in c sharp
int left = 0;
int right = nums.Count - 1;
Console.WriteLine(right);

while (left < right)
{
    Console.WriteLine("We are good");
    left += 1;
}
// Out:
// 9
// We are good
// We are good
// We are good
// We are good
// We are good
// We are good
// We are good
// We are good
// We are good

// %%
// calculating the mid to make sure I am using the right division operator
using System.Security.AccessControl;

int q = 9 / 8;
Console.WriteLine(q); // 1
// 9 / 8 returns an int maybe because I casted it 

double r = 9 / 8;
Console.WriteLine(r); // 1
// I also get 1. 

float s = 9 / 8;
Console.WriteLine(s);
// It's all about the division

// using literals or hardcoded decimal
double t = 9.0 / 8;
Console.WriteLine(t);

Console.WriteLine($"left: {left}");
Console.WriteLine($"right: {right}");
int mid = (left + right + 1) / 2;
Console.WriteLine(mid);
// Out:
// 1
// 1
// 1
// 1.125
// left: 9
// right: 9
// 9

// %%
List<int> nums = [];
for (int i = 0; i < 10; i += 2)
{
    nums.Add(i);
}

int right = nums.Count;
int left = 0;

Console.Write('[');
foreach (int i in nums)
{
    Console.Write($"{i},");    
}
Console.Write(']');
Console.WriteLine();
int target = 6;
Console.WriteLine($"left: {left}");
Console.WriteLine($"right: {right}");
while (left < right)
{
    int mid = (left + right + 1) / 2;
    Console.WriteLine($"mid: {mid}");
    if (nums[mid] == target)
    {
        Console.WriteLine($"The index is {mid}");
    }
    else if (target > nums[mid]) {
        right = mid - 1;
    }
    else 
    {
        left = mid + 1;   
    }
}
// Out:
// [0,2,4,6,8,]
// left: 0
// right: 5
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// mid: 3
// The index is 3
// ...
